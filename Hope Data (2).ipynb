# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# This notebook explores and summarizes Data Science Tools and its Ecosystem.

# %% [markdown]
# **Objectives**
# - Data Science Languages
# - Data Science Libraries
# - Arithmetic expressions

# %% [markdown]
# ## Data Science Languages

# %% [markdown]
# Some of the popular languages that Data Scientist use to organize and process data include:

# %% [markdown]
# 1. Python
# 2. SQL
# 3. R

# %% [markdown]
# ## Data Science Libraries

# %% [markdown]
# Commonly used libraries include:

# %% [markdown]
# - Pandas
# - Numpy
# - Seaborn
# - Plotly
# - Metaplotlib
# - ggplot (R)

# %% [markdown]
# Below includes open source tools that are available for data science:

# %% [markdown]
# | Data Science Tools |
# |--------|
#  |Jupyter Notebook|
#  | RStudio|
#  |Jupyterlab|

# %% [markdown]
# ### Below are a few examples of evaluating arithmetic expressions in Python:

# %%
# This is a simple arithmetic expression to multiply then add integers

# %%
(3*4)+5
# Out:
# 17

# %% [markdown]
# To find soultion, choose code, then click 'run' to execute the sum of this equation.

# %% [markdown]
# *This will convert 200 minutes to hours by dividing by 60.*

# %%
(200/60)
# Out:
# 3.3333333333333335

# %% [markdown]
# This answer proves that 200 minutes is equal to three hours and thrity-three minutes.

# %% [markdown]
# ## Author
# -------
# Hope Humphries
