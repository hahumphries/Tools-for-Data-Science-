# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# This notebook explores and summarizes Data Science Tools and Ecosystem

# %% [markdown]
# **Objectives:**
# - Add comments to code
# - Create markdown cells
# - Add ordered and unordered list
# - Create arithmetic expressions

# %% [markdown]
# ## Data Science Languages

# %% [markdown]
# Some of the popular langauges that Data Scientist use include:

# %% [markdown]
# 1. Python
# 2. R
# 3. SQL
# 4. Java
# 5. C++

# %% [markdown]
# ## Libraries

# %% [markdown]
# Some commonly used libraries used by Data Scientist include:

# %% [markdown]
# 1. Pandas
# 2. Numpy
# 3. Matplotlib
# 4. Tensorflow

# %% [markdown]
# ## Data Science Tools

# %% [markdown]
# | Data Science tools|
# | ------------------ |
# Jupyter Notebooks
# RStudio
# Anaconda

# %% [markdown]
# Below are a few examples of evualting artihmetic expressions in Python:

# %%
#This is a simple arithmetic expression to multiply then add integers
(3*4)+5
# Out:
# 17

# %%
#This is an example of converting minutes to hours 
200//60
# Out:
# 3

# %% [markdown]
# # Author

# %% [markdown]
# Hope Humphries
